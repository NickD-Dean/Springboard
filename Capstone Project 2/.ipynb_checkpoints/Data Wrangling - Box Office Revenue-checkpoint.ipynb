# %% [markdown]
# # Box Office Revenue Predictictive Models
#
# ### Data Wrangling Notebook
#
#
# The purpose of this project is to further practice building my own models in order to build and evaluate the performance of models that predict the revenue of movies, as a function of features associated with them.
#
# These models will be evaluated against relevant KPI's (R-squared, Mean Absolute Error, MAE^2), and the best model will be used to predict revenue performance for movies in a world where theaters continued to stay open in 2020 and 2021.
#
# This notebook's purpose is to prepare the data set(s) for exploratory analysis in a subsequent notebook.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

# %% [markdown]
# **Load Box office data**
#
# Here I load in both .csv files with the box-office data.  The data was pre-split for a Kaggle competition years ago. In this instance I chose to merge both files into a single dataframe and later will use SciKit Learn to create a new train/test split for modeling.
#
# Data Source:
#
# Kaggle. (May 2019). TMDB Box Office Prediction, V1. Retrieved 04/16/2021 from https://www.kaggle.com/c/tmdb-box-office-prediction/data.

# %%
box_office_train_data = pd.read_csv(r'C:\Users\deann\Documents\Data\Box Office Prediction Data\train.csv')
box_office_test_data = pd.read_csv(r'C:\Users\deann\Documents\Data\Box Office Prediction Data\test.csv')

box_office_train_data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# Pulling up basic summary statistics for both .csv's

# %%
box_office_train_data.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
box_office_test_data.describe()
# Out:
#                 id        budget   popularity      runtime
# count  4398.000000  4.398000e+03  4398.000000  4394.000000
# mean   5199.500000  2.264929e+07     8.550230   107.622212
# std    1269.737571  3.689991e+07    12.209014    21.058290
# min    3001.000000  0.000000e+00     0.000001     0.000000
# 25%    4100.250000  0.000000e+00     3.895186    94.000000
# 50%    5199.500000  7.450000e+06     7.482241   104.000000
# 75%    6298.750000  2.800000e+07    10.938524   118.000000
# max    7398.000000  2.600000e+08   547.488298   320.000000

# %% [markdown]
# Here I can see that there are few numeric features for this dataset - determining what other data types I'll be working with is going to be important before going too far with the data here.

# %% [markdown]
# At this point it seems that both the train and test data provided really should be combined into a single data frame.  There isn't a compelling reason to keep the data partitioned while I go through data wrangling and EDA.  I can separate out the portions of data without revenue data to recreate my train/test split later on - the work that will require is significanly less than duplicating all of the work needed for data wrangling and exploratory analysis.
#
# I'm also going to remove the scientific notation from Pandas for this dataset.  The maximum numeric value in the entire set is 380 million - which has more digits when written with scientific notation than without.  In a different scenario the notation might be helpful but since it's not something I use regularly I'll remove it for the time being to make my data more readable.

# %%
boxoffice = pd.concat([box_office_test_data, box_office_train_data])

pd.set_option('display.float_format', lambda x: '%.5f' % x)

boxoffice.describe()
# Out:
#               id          budget  popularity    runtime          revenue
# count 7398.00000      7398.00000  7398.00000 7392.00000       3000.00000
# mean  3699.50000  22601457.78102     8.51497  107.71726   66725851.88867
# std   2135.76298  36948673.26211    12.16579   21.48004  137532326.33602
# min      1.00000         0.00000     0.00000    0.00000          1.00000
# 25%   1850.25000         0.00000     3.93312   94.00000    2379808.25000
# 50%   3699.50000   7500000.00000     7.43584  104.00000   16807068.00000
# 75%   5548.75000  28000000.00000    10.92000  118.00000   68919203.50000
# max   7398.00000 380000000.00000   547.48830  338.00000 1519557910.00000

# %% [markdown]
# While removing scientific notation does make this more readable - the floats have and unessecary degree of precision and I'd like to include some comma separators for mroe readability so I'll adjust that pandas setting here as well.
#
# It's time to take a look at the first portion of the combined data frame as well.

# %%
pd.options.display.float_format = '{:,.2f}'.format

boxoffice.head(20)
# Out:
#       id                              belongs_to_collection     budget  \
# 0   3001  [{'id': 34055, 'name': 'Pokémon Collection', '...          0
# 1   3002                                                NaN      88000
# 2   3003                                                NaN          0
# 3   3004                                                NaN    6800000
# 4   3005                                                NaN    2000000
# 5   3006                                                NaN          0
# 6   3007                                                NaN          0
# 7   3008                                                NaN   30000000
# 8   3009                                                NaN   16500000
# 9   3010  [{'id': 10194, 'name': 'Toy Story Collection',...   90000000
# 10  3011                                                NaN    2000000
# 11  3012                                                NaN          0
# 12  3013  [{'id': 87805, 'name': 'The Gods Must Be Crazy...    5000000
# 13  3014                                                NaN     800000
# 14  3015                                                NaN   20000000
# 15  3016                                                NaN          0
# 16  3017  [{'id': 313576, 'name': 'Hot Tub Time Machine ...   36000000
# 17  3018                                                NaN  100000000
# 18  3019                                                NaN          0
# 19  3020                                                NaN  200000000
#
#                                                genres  \
# 0   [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1   [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2   [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3   [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4   [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
# 5   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 6   [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 7   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 8   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 9   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 10  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 11                      [{'id': 18, 'name': 'Drama'}]
# 12  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 13  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 14  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 15                      [{'id': 18, 'name': 'Drama'}]
# 16  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 17  [{'id': 53, 'name': 'Thriller'}, {'id': 878, '...
# 18  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 19  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                              homepage    imdb_id  \
# 0   http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                 NaN  tt0051380
# 2                                                 NaN  tt0118556
# 3              http://www.sonyclassics.com/incendies/  tt1255953
# 4                                                 NaN  tt0418753
# 5                                                 NaN  tt0120238
# 6                                                 NaN  tt1517177
# 7                               http://www.tigger.com  tt0220099
# 8                   http://becomingjane-themovie.com/  tt0416508
# 9              http://toystory.disney.com/toy-story-2  tt0120363
# 10                                                NaN  tt0419663
# 11                                                NaN  tt3655522
# 12                                                NaN  tt0080801
# 13                      http://www.lhp.com.sg/victor/  tt0316188
# 14                      http://www.brothersbloom.com/  tt0844286
# 15               http://www.beautifulboythemovie.com/  tt1533013
# 16        http://www.mgm.com/view/Movie/2387/Hot-T...  tt1231587
# 17                                                NaN  tt2209764
# 18                                                NaN  tt0078754
# 19                        http://www.titanicmovie.com  tt0120338
#
#    original_language               original_title  \
# 0                 ja           ディアルガVSパルキアVSダークライ
# 1                 en  Attack of the 50 Foot Woman
# 2                 en             Addicted to Love
# 3                 fr                    Incendies
# 4                 en           Inside Deep Throat
# 5                 en                     SubUrbia
# 6                 de                         Drei
# 7                 en             The Tigger Movie
# 8                 en                Becoming Jane
# 9                 en                  Toy Story 2
# 10                en                  Cruel World
# 11                fr              Bande de filles
# 12                en       The Gods Must Be Crazy
# 13                en        Raising Victor Vargas
# 14                en           The Brothers Bloom
# 15                en                Beautiful Boy
# 16                en         Hot Tub Time Machine
# 17                en                Transcendence
# 18                en                All That Jazz
# 19                en                      Titanic
#
#                                              overview  popularity  ...  \
# 0   Ash and friends (this time accompanied by newc...        3.85  ...
# 1   When an abused wife grows to giant size becaus...        3.56  ...
# 2   Good-natured astronomer Sam is devastated when...        8.09  ...
# 3   A mother's last wishes send twins Jeanne and S...        8.60  ...
# 4   In 1972, a seemingly typical shoestring budget...        3.22  ...
# 5   A group of suburban teenagers try to support e...        8.68  ...
# 6   Hanna and Simon are in a 20 year marriage with...        4.90  ...
# 7   As it happens, everybody - Pooh, Piglet, Eeyor...        7.02  ...
# 8   A biographical portrait of a pre-fame Jane Aus...        7.83  ...
# 9   Andy heads off to Cowboy Camp, leaving his toy...       17.55  ...
# 10  Millions witnessed Philip Markham's public hum...        0.26  ...
# 11  Oppressed by her family setting, dead-end scho...        4.22  ...
# 12  Misery is brought to a small group of Sho in t...       10.97  ...
# 13  The film follows Victor, a Lower East Side tee...        1.18  ...
# 14  The Brothers Bloom are the best con men in the...        7.97  ...
# 15  A married couple on the verge of separation ar...        2.11  ...
# 16  A malfunctioning time machine at a ski resort ...       11.97  ...
# 17  Two leading computer scientists work toward th...        9.73  ...
# 18  Bob Fosse's semi-autobiographical film celebra...        5.63  ...
# 19  84 years later, a 101-year-old woman named Ros...       26.89  ...
#
#    release_date runtime                                   spoken_languages  \
# 0       7/14/07   90.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1       5/19/58   65.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 2       5/23/97  100.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        9/4/10  130.00  [{'iso_639_1': 'fr', 'name': 'Français'}, {'is...
# 4       2/11/05   92.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 5        2/7/96  121.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      12/23/10  119.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 7       2/11/00   77.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 8        3/2/07  120.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 9      10/30/99   92.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 10       9/1/05   88.00  [{'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso...
# 11      6/27/14  112.00          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 12      9/10/80  109.00  [{'iso_639_1': 'af', 'name': 'Afrikaans'}, {'i...
# 13      5/16/02   88.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 14       9/9/08  114.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 15      9/12/10  100.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 16      3/26/10  101.00  [{'iso_639_1': 'ru', 'name': 'Pусский'}, {'iso...
# 17      4/16/14  119.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 18     12/20/79  123.00           [{'iso_639_1': 'en', 'name': 'English'}]
# 19     11/18/97  194.00  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#       status                                            tagline  \
# 0   Released  Somewhere Between Time & Space... A Legend Is ...
# 1   Released  A titanic beauty spreads a macabre wave of hor...
# 2   Released          A Comedy About Lost Loves And Last Laughs
# 3   Released  The search began at the opening of their mothe...
# 4   Released  It was filmed in 6 days for 25 thousand dollar...
# 5   Released                                                NaN
# 6   Released                         Imagine the possibilities.
# 7   Released                                                NaN
# 8   Released          Her own life is her greatest inspiration.
# 9   Released                                 The toys are back!
# 10  Released  When You Get Voted Off This Reality Show... It...
# 11  Released                                                NaN
# 12  Released  The critics are raving... the natives are rest...
# 13  Released                                                NaN
# 14  Released      They'd never let the truth come between them.
# 15  Released  To confront the truth, first they had to face ...
# 16  Released                                     Kick some past
# 17  Released       Yesterday, Dr. Will Caster was only human...
# 18  Released  All that work. All that glitter. All that pain...
# 19  Released          Nothing on Earth could come between them.
#
#                            title  \
# 0   Pokémon: The Rise of Darkrai
# 1    Attack of the 50 Foot Woman
# 2               Addicted to Love
# 3                      Incendies
# 4             Inside Deep Throat
# 5                       SubUrbia
# 6                          Three
# 7               The Tigger Movie
# 8                  Becoming Jane
# 9                    Toy Story 2
# 10                   Cruel World
# 11                      Girlhood
# 12        The Gods Must Be Crazy
# 13         Raising Victor Vargas
# 14            The Brothers Bloom
# 15                 Beautiful Boy
# 16          Hot Tub Time Machine
# 17                 Transcendence
# 18                 All That Jazz
# 19                       Titanic
#
#                                              Keywords  \
# 0   [{'id': 11451, 'name': 'pok√©mon'}, {'id': 115...
# 1   [{'id': 9748, 'name': 'revenge'}, {'id': 9951,...
# 2   [{'id': 931, 'name': 'jealousy'}, {'id': 9673,...
# 3   [{'id': 378, 'name': 'prison'}, {'id': 539, 'n...
# 4   [{'id': 279, 'name': 'usa'}, {'id': 1228, 'nam...
# 5         [{'id': 10183, 'name': 'independent film'}]
# 6   [{'id': 572, 'name': 'sex'}, {'id': 154937, 'n...
# 7   [{'id': 3905, 'name': 'owl'}, {'id': 4144, 'na...
# 8   [{'id': 392, 'name': 'england'}, {'id': 934, '...
# 9   [{'id': 2598, 'name': 'museum'}, {'id': 3246, ...
# 10  [{'id': 2136, 'name': 'television'}, {'id': 30...
# 11  [{'id': 12990, 'name': 'singing'}, {'id': 1465...
# 12  [{'id': 409, 'name': 'africa'}, {'id': 3800, '...
# 13        [{'id': 10183, 'name': 'independent film'}]
# 14  [{'id': 3202, 'name': 'con man'}, {'id': 20313...
# 15  [{'id': 3446, 'name': 'forgiveness'}, {'id': 4...
# 16  [{'id': 293, 'name': 'female nudity'}, {'id': ...
# 17  [{'id': 310, 'name': 'artificial intelligence'...
# 18  [{'id': 837, 'name': 'show business'}, {'id': ...
# 19  [{'id': 2580, 'name': 'shipwreck'}, {'id': 298...
#
#                                                  cast  \
# 0   [{'cast_id': 3, 'character': 'Tonio', 'credit_...
# 1   [{'cast_id': 2, 'character': 'Nancy Fowler Arc...
# 2   [{'cast_id': 11, 'character': 'Maggie', 'credi...
# 3   [{'cast_id': 6, 'character': 'Nawal', 'credit_...
# 4   [{'cast_id': 1, 'character': 'Narrator (voice)...
# 5   [{'cast_id': 4, 'character': 'Pony', 'credit_i...
# 6   [{'cast_id': 2, 'character': 'Hanna', 'credit_...
# 7   [{'cast_id': 2, 'character': 'Tigger / Winnie ...
# 8   [{'cast_id': 10, 'character': 'Jane Austen', '...
# 9   [{'cast_id': 18, 'character': 'Woody (voice)',...
# 10  [{'cast_id': 1, 'character': 'Philip Markham',...
# 11  [{'cast_id': 5, 'character': 'Marieme, alias V...
# 12  [{'cast_id': 5, 'character': 'Xixo', 'credit_i...
# 13  [{'cast_id': 3, 'character': 'Victor Vargas', ...
# 14  [{'cast_id': 1, 'character': 'Penelope Stamp',...
# 15  [{'cast_id': 1, 'character': 'Bill Carroll', '...
# 16  [{'cast_id': 2, 'character': 'Adam', 'credit_i...
# 17  [{'cast_id': 2, 'character': 'Dr. Will Caster'...
# 18  [{'cast_id': 2, 'character': 'Joe Gideon', 'cr...
# 19  [{'cast_id': 20, 'character': 'Rose DeWitt Buk...
#
#                                                  crew revenue
# 0   [{'credit_id': '52fe44e7c3a368484e03d683', 'de...     nan
# 1   [{'credit_id': '55807805c3a3685b1300060b', 'de...     nan
# 2   [{'credit_id': '52fe4330c3a36847f8041367', 'de...     nan
# 3   [{'credit_id': '56478092c3a36826140043af', 'de...     nan
# 4   [{'credit_id': '52fe44ce9251416c75041967', 'de...     nan
# 5   [{'credit_id': '52fe4576c3a368484e05c901', 'de...     nan
# 6   [{'credit_id': '52fe485bc3a36847f816358d', 'de...     nan
# 7   [{'credit_id': '59121da0c3a3686519043247', 'de...     nan
# 8   [{'credit_id': '53569575c3a3687f54000051', 'de...     nan
# 9   [{'credit_id': '52fe4284c3a36847f8025073', 'de...     nan
# 10  [{'credit_id': '52fe4680c3a36847f81028a9', 'de...     nan
# 11  [{'credit_id': '53567267c3a36841d6002424', 'de...     nan
# 12  [{'credit_id': '52fe44a5c3a36847f80a1f6b', 'de...     nan
# 13  [{'credit_id': '52fe44c9c3a368484e036cd7', 'de...     nan
# 14  [{'credit_id': '52fe4426c3a368484e01239d', 'de...     nan
# 15  [{'credit_id': '52fe4990c3a36847f81a0cc3', 'de...     nan
# 16  [{'credit_id': '555adea1c3a3681089001472', 'de...     nan
# 17  [{'credit_id': '53fc4c480e0a267a6f00a3ac', 'de...     nan
# 18  [{'credit_id': '52fe46f09251416c75088863', 'de...     nan
# 19  [{'credit_id': '52fe425ac3a36847f8017985', 'de...     nan
#
# [20 rows x 23 columns]

# %% [markdown]
#  It seems that there are several values for which the data frame returns a dictionary: ***Cast, Crew, Keywords, Genres, 'Belongs to collection', and 'Spoken Languages'***.  All of these seem to be features which could conceivably contribute or indicate revenue potential for a movie, either by providing exposure (casting Tom Hanks as your lead), quality production value (bringing in Steven Spielberg as your EP), or expanding/adopting an existing market (action movies, zombie films, existing franchises like Star Wars, or a new country like China).
#
# For now I'm going to leave these in as-is however later on in this notebook I would like to be able to identify if a given collection, genre, actor, producer, or language is associated with a higher revenue.  It's likely that this will be served best by transforming these dictionaries into lists.  However I would like to do some more data cleaning before taking that step.

# %% [markdown]
# ***Missing Values:***
#
# In this section I'll take a look at missing values for the dataset and determine which, if any, columns to drop from the dataset.

# %%
missing = pd.concat([boxoffice.isnull().sum(),100*boxoffice.isnull().mean()], axis=1)
missing.columns = ['Count', '% Missing']
missing.sort_values(by='% Missing', ascending=False)
# Out:
#                        Count  % Missing
# belongs_to_collection   5917      79.98
# homepage                5032      68.02
# revenue                 4398      59.45
# tagline                 1460      19.74
# Keywords                 669       9.04
# production_companies     414       5.60
# production_countries     157       2.12
# spoken_languages          62       0.84
# crew                      38       0.51
# cast                      26       0.35
# genres                    23       0.31
# overview                  22       0.30
# runtime                    6       0.08
# title                      3       0.04
# poster_path                2       0.03
# status                     2       0.03
# release_date               1       0.01
# budget                     0       0.00
# original_language          0       0.00
# original_title             0       0.00
# imdb_id                    0       0.00
# popularity                 0       0.00
# id                         0       0.00

# %% [markdown]
# Based on the above it seems that missing values will not be a large impediment for this project.
#
# The test data set with 4398 rows does not have any revenue information (this is what we'll be predicting), so those missing values were expected.  It is worth noting that this will alter the data I can work with for exploratory analysis and it may be prudent to import revenue data for those films at the end of this notebook.
#
# There are significant missing values for both ***'Belongs to collection' and 'homepage'***, with 80% an 68% missing respectively.  These columns definitely warrant further review.
#
# The 'tagline' and 'Keywords' columns are missing less than 20% of their data and for now this seems workable.  Previously I've built accurate models with more data missing than that so I'll leave these columns alone for now.

# %% [markdown]
# ***Dealing with 'belongs_to_collection'***
#
# This is the column with the largest amount of missing values.  I need to determine what to do with this column, potentially turning it into a boolean value representing if the film belongs to a collection at all.
#
# Additionally this is a good opportunity to take a look at values which are lists or dictionaries in this data set since that will present interesting opportunities for analysis.

# %%
has_collection = boxoffice['belongs_to_collection'].notnull()

boxoffice['belongs_to_collection'][has_collection]   #I want to look at only actual values to better understand what they are
# Out:
# 0       [{'id': 34055, 'name': 'Pokémon Collection', '...
# 9       [{'id': 10194, 'name': 'Toy Story Collection',...
# 12      [{'id': 87805, 'name': 'The Gods Must Be Crazy...
# 16      [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# 28      [{'id': 409138, 'name': 'Yossi Collection', 'p...
#                               ...
# 2967    [{'id': 387219, 'name': 'The Hustler Collectio...
# 2968    [{'id': 97307, 'name': 'BloodRayne Collection'...
# 2974    [{'id': 149704, 'name': 'Alone in the Dark Col...
# 2984    [{'id': 221111, 'name': 'S.W.A.T. Collection',...
# 2991    [{'id': 107469, 'name': 'Save The Last Dance C...
# Name: belongs_to_collection, Length: 1481, dtype: object

# %%
pd.set_option("display.max_colwidth", None)    #updating pandas setting so that colums aren't truncated

boxoffice['belongs_to_collection'][has_collection]
# Out:
# 0                      [{'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}]
# 9                    [{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}]
# 12      [{'id': 87805, 'name': 'The Gods Must Be Crazy Collection', 'poster_path': '/3KAJpE2OOimXE5Z15LHARbeA0eC.jpg', 'backdrop_path': '/3u6As0EKP2KKPNhzQObCgdYvm7f.jpg'}]
# 16       [{'id': 313576, 'name': 'Hot Tub Time Machine Collection', 'poster_path': '/iEhb00TGPucF0b4joM1ieyY026U.jpg', 'backdrop_path': '/noeTVcgpBiD48fDjFVic1Vz7ope.jpg'}]
# 28                       [{'id': 409138, 'name': 'Yossi Collection', 'poster_path': '/y30egmXtXggkHA2yfcDQcmM9D90.jpg', 'backdrop_path': '/w5u8mlzQqpVWcZlCgHzgzHOwGm.jpg'}]
#                                                                                         ...
# 2967                                            [{'id': 387219, 'name': 'The Hustler Collection', 'poster_path': '/8kBQvshMpK76aET1hLfAxnDle5W.jpg', 'backdrop_path': None}]
# 2968                [{'id': 97307, 'name': 'BloodRayne Collection', 'poster_path': '/yDRE2eRQIGKKpW1AJ9WWolmccOQ.jpg', 'backdrop_path': '/tSiYzuDL8i3yyVyCnxGtwLjA3Tz.jpg'}]
# 2974        [{'id': 149704, 'name': 'Alone in the Dark Collection', 'poster_path': '/pCUq2wPTjmpRRTsatXWseAoMzyi.jpg', 'backdrop_path': '/uxhIfa4gqxh9rjGq3vPLoXjQLIY.jpg'}]
# 2984                 [{'id': 221111, 'name': 'S.W.A.T. Collection', 'poster_path': '/iaBn9GPUik9xwfHIelzTXJi5ClY.jpg', 'backdrop_path': '/75To7hSFaAuciz4EXAFfj4LH6Od.jpg'}]
# 2991                                    [{'id': 107469, 'name': 'Save The Last Dance Collection', 'poster_path': '/jAByXoHn29RlCjIrOa3k1jl60DB.jpg', 'backdrop_path': None}]
# Name: belongs_to_collection, Length: 1481, dtype: object

# %% [markdown]
# Now I can see that each value is a dictionary containing the ID, name, path to poster, adn path to backdrop for each collection.
#
# While it's possible that the backdrop and/or poster could have an impact on revenue for marketing reasons; I would need to asess them using computer vision which is not in the scope of this project.
#
# For now I'm going to replace this dictionary with only the name of each collection.

# %% [markdown]
# ### Summary
#
# -From the data provided "Belongs to collection" and "homepage" values had 80% and 68% missing values - this is significantly higher than any other column in the set.
#
# -I made the decision to keep all columns with less than 20% of their data missing
